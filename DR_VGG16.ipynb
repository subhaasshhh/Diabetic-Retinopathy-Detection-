# %% [markdown]
# # Import Libraries!

# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
from IPython.display import Image, display, Markdown
import matplotlib.cm as cm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from time import perf_counter
import seaborn as sns

def printmd(string):
    # Print with Markdowns    
    display(Markdown(string))

# %%
image_dir = Path('../input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images')

# Get filepaths and labels
filepaths = list(image_dir.glob(r'**/*.png'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result
image_df.head(3)
# Out:
#                                             Filepath     Label
# 0  ../input/diabetic-retinopathy-224x224-gaussian...  Moderate
# 1  ../input/diabetic-retinopathy-224x224-gaussian...     No_DR
# 2  ../input/diabetic-retinopathy-224x224-gaussian...  Moderate

# %% [markdown]
# # Data Visualization!

# %%
# Display some pictures of the dataset with their labels:

fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Display the number of pictures of each category:

vc = image_df['Label'].value_counts()
plt.figure(figsize=(9,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
def create_gen():
    # Load the Images with a generator and Data Augmentation:
    
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
        validation_split=0.1
    )

    test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
    )

    train_images = train_generator.flow_from_dataframe(
        dataframe=train_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=True,
        seed=0,
        subset='training',
        rotation_range=30, # Uncomment to use data augmentation!
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest"
    )

    val_images = train_generator.flow_from_dataframe(
        dataframe=train_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=True,
        seed=0,
        subset='validation',
        rotation_range=30, # Uncomment to use data augmentation!
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest"
    )

    test_images = test_generator.flow_from_dataframe(
        dataframe=test_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=False
    )
    
    return train_generator,test_generator,train_images,val_images,test_images

# %%
def get_model(model):
# Load the pretained model:

    kwargs =    {'input_shape':(224, 224, 3),
                'include_top':False,
                'weights':'imagenet',
                'pooling':'avg'}
    
    pretrained_model = model(**kwargs)
    pretrained_model.trainable = False
    
    inputs = pretrained_model.input

    x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
    x = tf.keras.layers.Dense(128, activation='relu')(x)

    outputs = tf.keras.layers.Dense(5, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
# Map the labels to have only "No_DR" and "DR":

image_df_red = image_df.copy()
image_df_red['Label'] = image_df_red['Label'].apply(lambda x: x if x == 'No_DR' else 'DR')
image_df_red.head(5)
# Out:
#                                             Filepath  Label
# 0  ../input/diabetic-retinopathy-224x224-gaussian...     DR
# 1  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 2  ../input/diabetic-retinopathy-224x224-gaussian...     DR
# 3  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 4  ../input/diabetic-retinopathy-224x224-gaussian...     DR

# %%
# Display the number of pictures of each category:

vc = image_df_red['Label'].value_counts()
plt.figure(figsize=(9,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
# Separate in train and test data:

train_df, test_df = train_test_split(image_df_red, train_size=0.9, shuffle=True, random_state=1)

# %%
# Create the generators
train_generator,test_generator,train_images,val_images,test_images=create_gen()

# Load the pretained model
pretrained_model = tf.keras.applications.VGG16(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False


inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(2, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy','AUC']
)
# Out:
# Found 2966 validated image filenames belonging to 2 classes.
# Found 329 validated image filenames belonging to 2 classes.
# Found 367 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/vgg16/vgg16_weights_tf_dim_ordering_tf_kernels_notop.h5
# 58892288/58889256 [==============================] - 0s 0us/step

# %%
history = model.fit(
    train_images,
    validation_data=val_images,
    batch_size = 32,
    epochs=50)
# Out:
# Epoch 1/50
# 93/93 [==============================] - 40s 326ms/step - loss: 0.4547 - accuracy: 0.7913 - auc: 0.8582 - val_loss: 0.1575 - val_accuracy: 0.9392 - val_auc: 0.9858
# Epoch 2/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.2123 - accuracy: 0.9238 - auc: 0.9699 - val_loss: 0.1390 - val_accuracy: 0.9514 - val_auc: 0.9890
# Epoch 3/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.1789 - accuracy: 0.9453 - auc: 0.9782 - val_loss: 0.1441 - val_accuracy: 0.9605 - val_auc: 0.9927
# Epoch 4/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.1769 - accuracy: 0.9453 - auc: 0.9775 - val_loss: 0.1363 - val_accuracy: 0.9483 - val_auc: 0.9901
# Epoch 5/50
# 93/93 [==============================] - 10s 108ms/step - loss: 0.1528 - accuracy: 0.9523 - auc: 0.9826 - val_loss: 0.1154 - val_accuracy: 0.9544 - val_auc: 0.9924
# Epoch 6/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.1573 - accuracy: 0.9516 - auc: 0.9821 - val_loss: 0.1085 - val_accuracy: 0.9635 - val_auc: 0.9931
# Epoch 7/50
# 93/93 [==============================] - 10s 112ms/step - loss: 0.1518 - accuracy: 0.9483 - auc: 0.9841 - val_loss: 0.1007 - val_accuracy: 0.9605 - val_auc: 0.9945
# Epoch 8/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.1493 - accuracy: 0.9543 - auc: 0.9837 - val_loss: 0.0992 - val_accuracy: 0.9635 - val_auc: 0.9941
# Epoch 9/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.1328 - accuracy: 0.9568 - auc: 0.9876 - val_loss: 0.1026 - val_accuracy: 0.9666 - val_auc: 0.9959
# Epoch 10/50
# 93/93 [==============================] - 10s 112ms/step - loss: 0.1389 - accuracy: 0.9514 - auc: 0.9876 - val_loss: 0.1041 - val_accuracy: 0.9666 - val_auc: 0.9957
# Epoch 11/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.1354 - accuracy: 0.9547 - auc: 0.9879 - val_loss: 0.0966 - val_accuracy: 0.9696 - val_auc: 0.9938
# Epoch 12/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.1595 - accuracy: 0.9485 - auc: 0.9824 - val_loss: 0.0939 - val_accuracy: 0.9726 - val_auc: 0.9946
# Epoch 13/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.1214 - accuracy: 0.9610 - auc: 0.9898 - val_loss: 0.1033 - val_accuracy: 0.9726 - val_auc: 0.9939
# Epoch 14/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.1332 - accuracy: 0.9525 - auc: 0.9885 - val_loss: 0.0890 - val_accuracy: 0.9726 - val_auc: 0.9958
# Epoch 15/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.1282 - accuracy: 0.9561 - auc: 0.9892 - val_loss: 0.0960 - val_accuracy: 0.9726 - val_auc: 0.9936
# Epoch 16/50
# 93/93 [==============================] - 11s 114ms/step - loss: 0.1001 - accuracy: 0.9694 - auc: 0.9924 - val_loss: 0.0889 - val_accuracy: 0.9666 - val_auc: 0.9961
# Epoch 17/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.1237 - accuracy: 0.9596 - auc: 0.9895 - val_loss: 0.0839 - val_accuracy: 0.9757 - val_auc: 0.9958
# Epoch 18/50
# 93/93 [==============================] - 10s 108ms/step - loss: 0.1157 - accuracy: 0.9588 - auc: 0.9905 - val_loss: 0.0884 - val_accuracy: 0.9696 - val_auc: 0.9942
# Epoch 19/50
# 93/93 [==============================] - 10s 112ms/step - loss: 0.0977 - accuracy: 0.9728 - auc: 0.9925 - val_loss: 0.1156 - val_accuracy: 0.9666 - val_auc: 0.9909
# Epoch 20/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.1140 - accuracy: 0.9583 - auc: 0.9913 - val_loss: 0.0952 - val_accuracy: 0.9696 - val_auc: 0.9939
# Epoch 21/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.1181 - accuracy: 0.9636 - auc: 0.9900 - val_loss: 0.0852 - val_accuracy: 0.9666 - val_auc: 0.9964
# Epoch 22/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.1239 - accuracy: 0.9580 - auc: 0.9900 - val_loss: 0.0917 - val_accuracy: 0.9666 - val_auc: 0.9956
# Epoch 23/50
# 93/93 [==============================] - 10s 112ms/step - loss: 0.1093 - accuracy: 0.9590 - auc: 0.9923 - val_loss: 0.0882 - val_accuracy: 0.9666 - val_auc: 0.9962
# Epoch 24/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.1170 - accuracy: 0.9606 - auc: 0.9904 - val_loss: 0.0779 - val_accuracy: 0.9696 - val_auc: 0.9967
# Epoch 25/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.1068 - accuracy: 0.9627 - auc: 0.9927 - val_loss: 0.1518 - val_accuracy: 0.9574 - val_auc: 0.9868
# Epoch 26/50
# 93/93 [==============================] - 10s 113ms/step - loss: 0.1454 - accuracy: 0.9545 - auc: 0.9860 - val_loss: 0.1200 - val_accuracy: 0.9666 - val_auc: 0.9911
# Epoch 27/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.1352 - accuracy: 0.9462 - auc: 0.9882 - val_loss: 0.0912 - val_accuracy: 0.9726 - val_auc: 0.9936
# Epoch 28/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.1130 - accuracy: 0.9620 - auc: 0.9916 - val_loss: 0.0802 - val_accuracy: 0.9757 - val_auc: 0.9955
# Epoch 29/50
# 93/93 [==============================] - 11s 112ms/step - loss: 0.0899 - accuracy: 0.9691 - auc: 0.9944 - val_loss: 0.0695 - val_accuracy: 0.9757 - val_auc: 0.9969
# Epoch 30/50
# 93/93 [==============================] - 10s 107ms/step - loss: 0.1092 - accuracy: 0.9604 - auc: 0.9923 - val_loss: 0.0777 - val_accuracy: 0.9726 - val_auc: 0.9957
# Epoch 31/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.0910 - accuracy: 0.9730 - auc: 0.9943 - val_loss: 0.0769 - val_accuracy: 0.9757 - val_auc: 0.9967
# Epoch 32/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.1084 - accuracy: 0.9622 - auc: 0.9925 - val_loss: 0.0910 - val_accuracy: 0.9696 - val_auc: 0.9949
# Epoch 33/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.1124 - accuracy: 0.9579 - auc: 0.9920 - val_loss: 0.1162 - val_accuracy: 0.9544 - val_auc: 0.9924
# Epoch 34/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.1169 - accuracy: 0.9600 - auc: 0.9908 - val_loss: 0.0743 - val_accuracy: 0.9726 - val_auc: 0.9966
# Epoch 35/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.0915 - accuracy: 0.9686 - auc: 0.9942 - val_loss: 0.0690 - val_accuracy: 0.9787 - val_auc: 0.9969
# Epoch 36/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.0946 - accuracy: 0.9688 - auc: 0.9939 - val_loss: 0.0670 - val_accuracy: 0.9757 - val_auc: 0.9973
# Epoch 37/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.0914 - accuracy: 0.9721 - auc: 0.9944 - val_loss: 0.0788 - val_accuracy: 0.9605 - val_auc: 0.9965
# Epoch 38/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0886 - accuracy: 0.9699 - auc: 0.9939 - val_loss: 0.0823 - val_accuracy: 0.9696 - val_auc: 0.9958
# Epoch 39/50
# 93/93 [==============================] - 10s 112ms/step - loss: 0.0748 - accuracy: 0.9762 - auc: 0.9961 - val_loss: 0.0821 - val_accuracy: 0.9726 - val_auc: 0.9937
# Epoch 40/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.0840 - accuracy: 0.9722 - auc: 0.9952 - val_loss: 0.0883 - val_accuracy: 0.9726 - val_auc: 0.9930
# Epoch 41/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0817 - accuracy: 0.9717 - auc: 0.9948 - val_loss: 0.0678 - val_accuracy: 0.9696 - val_auc: 0.9970
# Epoch 42/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.0778 - accuracy: 0.9749 - auc: 0.9952 - val_loss: 0.0728 - val_accuracy: 0.9726 - val_auc: 0.9965
# Epoch 43/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0897 - accuracy: 0.9661 - auc: 0.9946 - val_loss: 0.0704 - val_accuracy: 0.9696 - val_auc: 0.9974
# Epoch 44/50
# 93/93 [==============================] - 10s 108ms/step - loss: 0.0811 - accuracy: 0.9707 - auc: 0.9960 - val_loss: 0.0705 - val_accuracy: 0.9696 - val_auc: 0.9972
# Epoch 45/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.0765 - accuracy: 0.9709 - auc: 0.9958 - val_loss: 0.0756 - val_accuracy: 0.9726 - val_auc: 0.9969
# Epoch 46/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.1094 - accuracy: 0.9656 - auc: 0.9920 - val_loss: 0.0723 - val_accuracy: 0.9726 - val_auc: 0.9968
# Epoch 47/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.0769 - accuracy: 0.9758 - auc: 0.9961 - val_loss: 0.0751 - val_accuracy: 0.9726 - val_auc: 0.9962
# Epoch 48/50
# 93/93 [==============================] - 11s 114ms/step - loss: 0.0739 - accuracy: 0.9727 - auc: 0.9964 - val_loss: 0.0780 - val_accuracy: 0.9696 - val_auc: 0.9966
# Epoch 49/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0798 - accuracy: 0.9681 - auc: 0.9959 - val_loss: 0.0678 - val_accuracy: 0.9696 - val_auc: 0.9971
# Epoch 50/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.0784 - accuracy: 0.9723 - auc: 0.9956 - val_loss: 0.0934 - val_accuracy: 0.9605 - val_auc: 0.9947

# %% [markdown]
# # Plotting!

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

results = model.evaluate(test_images, verbose=0)

printmd(" ## Test Loss: {:.5f}".format(results[0]))
printmd("## Accuracy on the test set: {:.2f}%".format(results[1] * 100))
print('\n')
# Out:
#  ## Test Loss: 0.15133
# ## Accuracy on the test set: 95.37%

# %%
# Predict the label of the test_images:

pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label:

labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

from sklearn.metrics import classification_report
y_test = list(test_df.Label)
from sklearn import metrics
print('Accuracy:', np.round(metrics.accuracy_score(y_test,pred),5))
print('Precision:', np.round(metrics.precision_score(y_test,pred, average='weighted'),5))
print('Recall:', np.round(metrics.recall_score(y_test,pred, average='weighted'),5))
print('F1 Score:', np.round(metrics.f1_score(y_test,pred, average='weighted'),5))
print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test,pred),5))
print(classification_report(y_test, pred))
# Out:
# Accuracy: 0.95368
# Precision: 0.9544
# Recall: 0.95368
# F1 Score: 0.95369
# Cohen Kappa Score: 0.90737
#               precision    recall  f1-score   support
#
#           DR       0.93      0.97      0.95       177
#        No_DR       0.97      0.94      0.95       190
#
#     accuracy                           0.95       367
#    macro avg       0.95      0.95      0.95       367
# weighted avg       0.95      0.95      0.95       367

# %%
cf_matrix = confusion_matrix(y_test, pred, normalize='true')
plt.figure(figsize = (10,6))
sns.heatmap(cf_matrix, annot=True, xticklabels = sorted(set(y_test)), yticklabels = sorted(set(y_test)))
plt.title('Normalized Confusion Matrix')
plt.show()
