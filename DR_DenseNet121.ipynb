# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
from IPython.display import Image, display, Markdown
import matplotlib.cm as cm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from time import perf_counter
import seaborn as sns

def printmd(string):
    # Print with Markdowns    
    display(Markdown(string))

# %%
image_dir = Path('../input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images')

# Get filepaths and labels:

filepaths = list(image_dir.glob(r'**/*.png'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels:
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index:
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result:
image_df.head(3)
# Out:
#                                             Filepath     Label
# 0  ../input/diabetic-retinopathy-224x224-gaussian...  Moderate
# 1  ../input/diabetic-retinopathy-224x224-gaussian...     No_DR
# 2  ../input/diabetic-retinopathy-224x224-gaussian...     No_DR

# %%
# Display some pictures of the dataset with their labels:
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Display the number of pictures of each category:
vc = image_df['Label'].value_counts()
plt.figure(figsize=(9,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
def create_gen():
    # Load the Images with a generator and Data Augmentation
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
        validation_split=0.1
    )

    test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
    )

    train_images = train_generator.flow_from_dataframe(
        dataframe=train_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=True,
        seed=0,
        subset='training',
        rotation_range=30, # Uncomment to use data augmentation
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest"
    )

    val_images = train_generator.flow_from_dataframe(
        dataframe=train_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=True,
        seed=0,
        subset='validation',
        rotation_range=30, # Uncomment to use data augmentation
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest"
    )

    test_images = test_generator.flow_from_dataframe(
        dataframe=test_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=False
    )
    
    return train_generator,test_generator,train_images,val_images,test_images

# %%
def get_model(model):
# Load the pretained model
    kwargs =    {'input_shape':(224, 224, 3),
                'include_top':False,
                'weights':'imagenet',
                'pooling':'avg'}
    
    pretrained_model = model(**kwargs)
    pretrained_model.trainable = False
    
    inputs = pretrained_model.input

    x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
    x = tf.keras.layers.Dense(128, activation='relu')(x)

    outputs = tf.keras.layers.Dense(5, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
# Map the labels to have only "No_DR" and "DR":
image_df_red = image_df.copy()
image_df_red['Label'] = image_df_red['Label'].apply(lambda x: x if x == 'No_DR' else 'DR')
image_df_red.head(5)
# Out:
#                                             Filepath  Label
# 0  ../input/diabetic-retinopathy-224x224-gaussian...     DR
# 1  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 2  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 3  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 4  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR

# %%
# Display the number of pictures of each category:
vc = image_df_red['Label'].value_counts()
plt.figure(figsize=(9,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
# Separate in train and test data:
train_df, test_df = train_test_split(image_df_red, train_size=0.9, shuffle=True, random_state=1)

# %%
# Create the generators:
train_generator,test_generator,train_images,val_images,test_images=create_gen()

# Load the pretained model:
pretrained_model = tf.keras.applications.DenseNet121(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False


inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(2, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy','AUC']
)
# Out:
# Found 2966 validated image filenames belonging to 2 classes.
# Found 329 validated image filenames belonging to 2 classes.
# Found 367 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/densenet/densenet121_weights_tf_dim_ordering_tf_kernels_notop.h5
# 29089792/29084464 [==============================] - 0s 0us/step

# %%
history = model.fit(
    train_images,
    validation_data=val_images,
    batch_size = 32,
    epochs=50)
# Out:
# Epoch 1/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.0592 - accuracy: 0.9794 - auc: 0.9975 - val_loss: 0.1180 - val_accuracy: 0.9696 - val_auc: 0.9885
# Epoch 2/50
# Epoch 31/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.0124 - accuracy: 0.9956 - auc: 0.9999 - val_loss: 0.2038 - val_accuracy: 0.9696 - val_auc: 0.9825
# Epoch 32/50
# 93/93 [==============================] - 11s 123ms/step - loss: 0.0284 - accuracy: 0.9909 - auc: 0.9992 - val_loss: 0.1686 - val_accuracy: 0.9605 - val_auc: 0.9860
# Epoch 33/50
# 93/93 [==============================] - 11s 115ms/step - loss: 0.0067 - accuracy: 0.9987 - auc: 1.0000 - val_loss: 0.2216 - val_accuracy: 0.9574 - val_auc: 0.9778
# Epoch 34/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.0431 - accuracy: 0.9828 - auc: 0.9990 - val_loss: 0.2082 - val_accuracy: 0.9483 - val_auc: 0.9828
# Epoch 35/50
# 93/93 [==============================] - 11s 121ms/step - loss: 0.0248 - accuracy: 0.9892 - auc: 0.9993 - val_loss: 0.1392 - val_accuracy: 0.9605 - val_auc: 0.9893
# Epoch 36/50
# 93/93 [==============================] - 11s 115ms/step - loss: 0.0100 - accuracy: 0.9966 - auc: 1.0000 - val_loss: 0.1623 - val_accuracy: 0.9605 - val_auc: 0.9817
# Epoch 37/50
# 93/93 [==============================] - 11s 115ms/step - loss: 0.0076 - accuracy: 0.9973 - auc: 1.0000 - val_loss: 0.1633 - val_accuracy: 0.9635 - val_auc: 0.9818
# Epoch 38/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.0086 - accuracy: 0.9966 - auc: 1.0000 - val_loss: 0.2009 - val_accuracy: 0.9696 - val_auc: 0.9801
# Epoch 39/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.0085 - accuracy: 0.9966 - auc: 1.0000 - val_loss: 0.2809 - val_accuracy: 0.9514 - val_auc: 0.9735
# Epoch 40/50
# 93/93 [==============================] - 11s 115ms/step - loss: 0.0227 - accuracy: 0.9953 - auc: 0.9988 - val_loss: 0.2664 - val_accuracy: 0.9666 - val_auc: 0.9736
# Epoch 41/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.0263 - accuracy: 0.9919 - auc: 0.9992 - val_loss: 0.1621 - val_accuracy: 0.9666 - val_auc: 0.9849
# Epoch 42/50
# 93/93 [==============================] - 11s 114ms/step - loss: 0.0142 - accuracy: 0.9956 - auc: 0.9999 - val_loss: 0.1793 - val_accuracy: 0.9726 - val_auc: 0.9828
# Epoch 43/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.0089 - accuracy: 0.9970 - auc: 1.0000 - val_loss: 0.1657 - val_accuracy: 0.9696 - val_auc: 0.9828
# Epoch 44/50
# 93/93 [==============================] - 11s 119ms/step - loss: 0.0193 - accuracy: 0.9916 - auc: 0.9995 - val_loss: 0.1657 - val_accuracy: 0.9666 - val_auc: 0.9883
# Epoch 45/50
# 93/93 [==============================] - 11s 114ms/step - loss: 0.0160 - accuracy: 0.9929 - auc: 0.9999 - val_loss: 0.2082 - val_accuracy: 0.9635 - val_auc: 0.9787
# Epoch 46/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.0294 - accuracy: 0.9899 - auc: 0.9992 - val_loss: 0.1958 - val_accuracy: 0.9666 - val_auc: 0.9825
# Epoch 47/50
# 93/93 [==============================] - 11s 122ms/step - loss: 0.0156 - accuracy: 0.9939 - auc: 0.9999 - val_loss: 0.1700 - val_accuracy: 0.9696 - val_auc: 0.9813
# Epoch 48/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.0062 - accuracy: 0.9980 - auc: 1.0000 - val_loss: 0.1845 - val_accuracy: 0.9666 - val_auc: 0.9797
# Epoch 49/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.0052 - accuracy: 0.9983 - auc: 1.0000 - val_loss: 0.1653 - val_accuracy: 0.9696 - val_auc: 0.9796
# Epoch 50/50
# 93/93 [==============================] - 11s 118ms/step - loss: 0.0039 - accuracy: 0.9987 - auc: 1.0000 - val_loss: 0.2198 - val_accuracy: 0.9666 - val_auc: 0.9795

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

results = model.evaluate(test_images, verbose=0)

printmd(" ## Test Loss: {:.5f}".format(results[0]))
printmd("## Accuracy on the test set: {:.2f}%".format(results[1] * 100))
print('\n')
# Out:
#  ## Test Loss: 0.29389
# ## Accuracy on the test set: 95.91%

# %%
# Predict the label of the test_images:
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label:
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

from sklearn.metrics import classification_report
y_test = list(test_df.Label)
from sklearn import metrics
print('Accuracy:', np.round(metrics.accuracy_score(y_test,pred),5))
print('Precision:', np.round(metrics.precision_score(y_test,pred, average='weighted'),5))
print('Recall:', np.round(metrics.recall_score(y_test,pred, average='weighted'),5))
print('F1 Score:', np.round(metrics.f1_score(y_test,pred, average='weighted'),5))
print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test,pred),5))
print(classification_report(y_test, pred))
# Out:
# Accuracy: 0.95913
# Precision: 0.95948
# Recall: 0.95913
# F1 Score: 0.95913
# Cohen Kappa Score: 0.91827
#               precision    recall  f1-score   support
#
#           DR       0.95      0.97      0.96       182
#        No_DR       0.97      0.95      0.96       185
#
#     accuracy                           0.96       367
#    macro avg       0.96      0.96      0.96       367
# weighted avg       0.96      0.96      0.96       367

# %%
cf_matrix = confusion_matrix(y_test, pred, normalize='true')
plt.figure(figsize = (10,6))
sns.heatmap(cf_matrix, annot=True, xticklabels = sorted(set(y_test)), yticklabels = sorted(set(y_test)))
plt.title('Normalized Confusion Matrix')
plt.show()
