# %%
import numpy as np
import pandas as pd
from pathlib import Path
import os.path
import matplotlib.pyplot as plt
from IPython.display import Image, display, Markdown
import matplotlib.cm as cm
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
import tensorflow as tf
from time import perf_counter
import seaborn as sns

def printmd(string):
    # Print with Markdowns:   
    display(Markdown(string))

# %%
image_dir = Path('../input/diabetic-retinopathy-224x224-gaussian-filtered/gaussian_filtered_images/gaussian_filtered_images')

# Get filepaths and labels:
filepaths = list(image_dir.glob(r'**/*.png'))
labels = list(map(lambda x: os.path.split(os.path.split(x)[0])[1], filepaths))

# %%
filepaths = pd.Series(filepaths, name='Filepath').astype(str)
labels = pd.Series(labels, name='Label')

# Concatenate filepaths and labels:
image_df = pd.concat([filepaths, labels], axis=1)

# Shuffle the DataFrame and reset index:
image_df = image_df.sample(frac=1).reset_index(drop = True)

# Show the result:
image_df.head(3)
# Out:
#                                             Filepath  Label
# 0  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 1  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 2  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR

# %%
# Display some pictures of the dataset with their labels:
fig, axes = plt.subplots(nrows=3, ncols=4, figsize=(10, 7),
                        subplot_kw={'xticks': [], 'yticks': []})

for i, ax in enumerate(axes.flat):
    ax.imshow(plt.imread(image_df.Filepath[i]))
    ax.set_title(image_df.Label[i])
plt.tight_layout()
plt.show()

# %%
# Display the number of pictures of each category:
vc = image_df['Label'].value_counts()
plt.figure(figsize=(9,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
def create_gen():
    # Load the Images with a generator and Data Augmentation:
    train_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input,
        validation_split=0.1
    )

    test_generator = tf.keras.preprocessing.image.ImageDataGenerator(
        preprocessing_function=tf.keras.applications.mobilenet_v2.preprocess_input
    )

    train_images = train_generator.flow_from_dataframe(
        dataframe=train_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=True,
        seed=0,
        subset='training',
        rotation_range=30, # Uncomment to use data augmentation!
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest"
    )

    val_images = train_generator.flow_from_dataframe(
        dataframe=train_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=True,
        seed=0,
        subset='validation',
        rotation_range=30, # Uncomment to use data augmentation!
        zoom_range=0.15,
        width_shift_range=0.2,
        height_shift_range=0.2,
        shear_range=0.15,
        horizontal_flip=True,
        fill_mode="nearest"
    )

    test_images = test_generator.flow_from_dataframe(
        dataframe=test_df,
        x_col='Filepath',
        y_col='Label',
        target_size=(224, 224),
        color_mode='rgb',
        class_mode='categorical',
        batch_size=32,
        shuffle=False
    )
    
    return train_generator,test_generator,train_images,val_images,test_images

# %%
def get_model(model):
# Load the pretained model:
    kwargs =    {'input_shape':(224, 224, 3),
                'include_top':False,
                'weights':'imagenet',
                'pooling':'avg'}
    
    pretrained_model = model(**kwargs)
    pretrained_model.trainable = False
    
    inputs = pretrained_model.input

    x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
    x = tf.keras.layers.Dense(128, activation='relu')(x)

    outputs = tf.keras.layers.Dense(5, activation='softmax')(x)

    model = tf.keras.Model(inputs=inputs, outputs=outputs)

    model.compile(
        optimizer='adam',
        loss='categorical_crossentropy',
        metrics=['accuracy']
    )
    
    return model

# %%
# Map the labels to have only "No_DR" and "DR":
image_df_red = image_df.copy()
image_df_red['Label'] = image_df_red['Label'].apply(lambda x: x if x == 'No_DR' else 'DR')
image_df_red.head(5)
# Out:
#                                             Filepath  Label
# 0  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 1  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 2  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 3  ../input/diabetic-retinopathy-224x224-gaussian...  No_DR
# 4  ../input/diabetic-retinopathy-224x224-gaussian...     DR

# %%
# Display the number of pictures of each category:
vc = image_df_red['Label'].value_counts()
plt.figure(figsize=(9,5))
sns.barplot(x = vc.index, y = vc, palette = "rocket")
plt.title("Number of pictures of each category", fontsize = 15)
plt.show()

# %%
# Separate in train and test data:
train_df, test_df = train_test_split(image_df_red, train_size=0.9, shuffle=True, random_state=1)

# %%
# Create the generators:
train_generator,test_generator,train_images,val_images,test_images=create_gen()

# Load the pretained model:
pretrained_model = tf.keras.applications.InceptionV3(
    input_shape=(224, 224, 3),
    include_top=False,
    weights='imagenet',
    pooling='avg'
)

pretrained_model.trainable = False


inputs = pretrained_model.input

x = tf.keras.layers.Dense(128, activation='relu')(pretrained_model.output)
x = tf.keras.layers.Dense(128, activation='relu')(x)

outputs = tf.keras.layers.Dense(2, activation='softmax')(x)

model = tf.keras.Model(inputs=inputs, outputs=outputs)

model.compile(
    optimizer='adam',
    loss='categorical_crossentropy',
    metrics=['accuracy','AUC']
)
# Out:
# Found 2966 validated image filenames belonging to 2 classes.
# Found 329 validated image filenames belonging to 2 classes.
# Found 367 validated image filenames belonging to 2 classes.
# Downloading data from https://storage.googleapis.com/tensorflow/keras-applications/inception_v3/inception_v3_weights_tf_dim_ordering_tf_kernels_notop.h5
# 87916544/87910968 [==============================] - 1s 0us/step

# %%
history = model.fit(
    train_images,
    validation_data=val_images,
    batch_size = 32,
    epochs=50)
# Out:
# Epoch 1/50
# 93/93 [==============================] - 34s 257ms/step - loss: 0.3409 - accuracy: 0.8426 - auc: 0.9152 - val_loss: 0.1318 - val_accuracy: 0.9544 - val_auc: 0.9889
# Epoch 2/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.1585 - accuracy: 0.9455 - auc: 0.9827 - val_loss: 0.1774 - val_accuracy: 0.9240 - val_auc: 0.9805
# Epoch 3/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.1581 - accuracy: 0.9451 - auc: 0.9837 - val_loss: 0.1044 - val_accuracy: 0.9696 - val_auc: 0.9914
# Epoch 4/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.1163 - accuracy: 0.9628 - auc: 0.9908 - val_loss: 0.1070 - val_accuracy: 0.9635 - val_auc: 0.9900
# Epoch 5/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.1096 - accuracy: 0.9620 - auc: 0.9920 - val_loss: 0.1186 - val_accuracy: 0.9574 - val_auc: 0.9895
# Epoch 6/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.1031 - accuracy: 0.9641 - auc: 0.9930 - val_loss: 0.2370 - val_accuracy: 0.9119 - val_auc: 0.9759
# Epoch 7/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0987 - accuracy: 0.9651 - auc: 0.9933 - val_loss: 0.1058 - val_accuracy: 0.9666 - val_auc: 0.9904
# Epoch 8/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.0743 - accuracy: 0.9710 - auc: 0.9966 - val_loss: 0.1114 - val_accuracy: 0.9635 - val_auc: 0.9902
# Epoch 9/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.0756 - accuracy: 0.9734 - auc: 0.9963 - val_loss: 0.1539 - val_accuracy: 0.9422 - val_auc: 0.9866
# Epoch 10/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0762 - accuracy: 0.9706 - auc: 0.9957 - val_loss: 0.1107 - val_accuracy: 0.9635 - val_auc: 0.9903
# Epoch 11/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.0645 - accuracy: 0.9765 - auc: 0.9976 - val_loss: 0.1172 - val_accuracy: 0.9666 - val_auc: 0.9881
# Epoch 12/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.0448 - accuracy: 0.9845 - auc: 0.9987 - val_loss: 0.1077 - val_accuracy: 0.9666 - val_auc: 0.9899
# Epoch 13/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.0495 - accuracy: 0.9833 - auc: 0.9985 - val_loss: 0.1091 - val_accuracy: 0.9696 - val_auc: 0.9894
# Epoch 14/50
# 93/93 [==============================] - 10s 108ms/step - loss: 0.0413 - accuracy: 0.9849 - auc: 0.9991 - val_loss: 0.1193 - val_accuracy: 0.9696 - val_auc: 0.9900
# Epoch 15/50
# 93/93 [==============================] - 10s 109ms/step - loss: 0.0332 - accuracy: 0.9882 - auc: 0.9991 - val_loss: 0.1327 - val_accuracy: 0.9605 - val_auc: 0.9895
# Epoch 16/50
# 93/93 [==============================] - 11s 115ms/step - loss: 0.0530 - accuracy: 0.9780 - auc: 0.9983 - val_loss: 0.1289 - val_accuracy: 0.9605 - val_auc: 0.9885
# Epoch 17/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.0352 - accuracy: 0.9850 - auc: 0.9993 - val_loss: 0.2245 - val_accuracy: 0.9210 - val_auc: 0.9767
# Epoch 18/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0455 - accuracy: 0.9840 - auc: 0.9986 - val_loss: 0.1600 - val_accuracy: 0.9483 - val_auc: 0.9873
# Epoch 19/50
# 93/93 [==============================] - 11s 114ms/step - loss: 0.0281 - accuracy: 0.9926 - auc: 0.9989 - val_loss: 0.1534 - val_accuracy: 0.9605 - val_auc: 0.9848
# Epoch 20/50
# 93/93 [==============================] - 10s 112ms/step - loss: 0.0227 - accuracy: 0.9928 - auc: 0.9997 - val_loss: 0.2702 - val_accuracy: 0.9240 - val_auc: 0.9696
# Epoch 21/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0575 - accuracy: 0.9809 - auc: 0.9977 - val_loss: 0.1504 - val_accuracy: 0.9666 - val_auc: 0.9903
# Epoch 22/50
# 93/93 [==============================] - 11s 114ms/step - loss: 0.0279 - accuracy: 0.9907 - auc: 0.9995 - val_loss: 0.2077 - val_accuracy: 0.9544 - val_auc: 0.9825
# Epoch 23/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0172 - accuracy: 0.9927 - auc: 0.9998 - val_loss: 0.1435 - val_accuracy: 0.9726 - val_auc: 0.9873
# Epoch 24/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.0125 - accuracy: 0.9959 - auc: 0.9999 - val_loss: 0.1878 - val_accuracy: 0.9574 - val_auc: 0.9858
# Epoch 25/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.0147 - accuracy: 0.9934 - auc: 0.9999 - val_loss: 0.1719 - val_accuracy: 0.9696 - val_auc: 0.9872
# Epoch 26/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0112 - accuracy: 0.9961 - auc: 0.9999 - val_loss: 0.1944 - val_accuracy: 0.9635 - val_auc: 0.9846
# Epoch 27/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.0161 - accuracy: 0.9927 - auc: 0.9998 - val_loss: 0.2046 - val_accuracy: 0.9726 - val_auc: 0.9805
# Epoch 28/50
# 93/93 [==============================] - 11s 113ms/step - loss: 0.0104 - accuracy: 0.9958 - auc: 0.9999 - val_loss: 0.1657 - val_accuracy: 0.9635 - val_auc: 0.9862
# Epoch 29/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0222 - accuracy: 0.9896 - auc: 0.9997 - val_loss: 0.3252 - val_accuracy: 0.9119 - val_auc: 0.9687
# Epoch 30/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0451 - accuracy: 0.9852 - auc: 0.9983 - val_loss: 0.1818 - val_accuracy: 0.9635 - val_auc: 0.9792
# Epoch 31/50
# 93/93 [==============================] - 11s 114ms/step - loss: 0.0166 - accuracy: 0.9954 - auc: 0.9998 - val_loss: 0.1968 - val_accuracy: 0.9605 - val_auc: 0.9823
# Epoch 32/50
# 93/93 [==============================] - 12s 131ms/step - loss: 0.0209 - accuracy: 0.9924 - auc: 0.9997 - val_loss: 0.1562 - val_accuracy: 0.9726 - val_auc: 0.9856
# Epoch 33/50
# 93/93 [==============================] - 13s 145ms/step - loss: 0.0085 - accuracy: 0.9962 - auc: 1.0000 - val_loss: 0.1771 - val_accuracy: 0.9666 - val_auc: 0.9846
# Epoch 34/50
# 93/93 [==============================] - 14s 148ms/step - loss: 0.0060 - accuracy: 0.9971 - auc: 1.0000 - val_loss: 0.2090 - val_accuracy: 0.9483 - val_auc: 0.9825
# Epoch 35/50
# 93/93 [==============================] - 13s 137ms/step - loss: 0.0083 - accuracy: 0.9984 - auc: 0.9999 - val_loss: 0.2062 - val_accuracy: 0.9696 - val_auc: 0.9856
# Epoch 36/50
# 93/93 [==============================] - 12s 126ms/step - loss: 0.0146 - accuracy: 0.9930 - auc: 0.9997 - val_loss: 0.2025 - val_accuracy: 0.9544 - val_auc: 0.9836
# Epoch 37/50
# 93/93 [==============================] - 12s 128ms/step - loss: 0.0137 - accuracy: 0.9944 - auc: 0.9999 - val_loss: 0.2475 - val_accuracy: 0.9392 - val_auc: 0.9803
# Epoch 38/50
# 93/93 [==============================] - 12s 127ms/step - loss: 0.0071 - accuracy: 0.9974 - auc: 1.0000 - val_loss: 0.2906 - val_accuracy: 0.9544 - val_auc: 0.9781
# Epoch 39/50
# 93/93 [==============================] - 11s 116ms/step - loss: 0.0251 - accuracy: 0.9926 - auc: 0.9987 - val_loss: 0.3291 - val_accuracy: 0.9453 - val_auc: 0.9745
# Epoch 40/50
# 93/93 [==============================] - 13s 134ms/step - loss: 0.0494 - accuracy: 0.9823 - auc: 0.9959 - val_loss: 0.1871 - val_accuracy: 0.9635 - val_auc: 0.9833
# Epoch 41/50
# 93/93 [==============================] - 11s 117ms/step - loss: 0.0057 - accuracy: 0.9968 - auc: 1.0000 - val_loss: 0.2190 - val_accuracy: 0.9605 - val_auc: 0.9814
# Epoch 42/50
# 93/93 [==============================] - 11s 114ms/step - loss: 0.0043 - accuracy: 0.9992 - auc: 1.0000 - val_loss: 0.2173 - val_accuracy: 0.9605 - val_auc: 0.9778
# Epoch 43/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0072 - accuracy: 0.9965 - auc: 1.0000 - val_loss: 0.2346 - val_accuracy: 0.9544 - val_auc: 0.9780
# Epoch 44/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0034 - accuracy: 0.9986 - auc: 1.0000 - val_loss: 0.2656 - val_accuracy: 0.9605 - val_auc: 0.9781
# Epoch 45/50
# 93/93 [==============================] - 10s 112ms/step - loss: 0.0086 - accuracy: 0.9958 - auc: 1.0000 - val_loss: 0.2033 - val_accuracy: 0.9635 - val_auc: 0.9844
# Epoch 46/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0054 - accuracy: 0.9974 - auc: 1.0000 - val_loss: 0.2175 - val_accuracy: 0.9726 - val_auc: 0.9766
# Epoch 47/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0027 - accuracy: 0.9995 - auc: 0.9998 - val_loss: 0.2378 - val_accuracy: 0.9544 - val_auc: 0.9801
# Epoch 48/50
# 93/93 [==============================] - 11s 114ms/step - loss: 0.0057 - accuracy: 0.9983 - auc: 1.0000 - val_loss: 0.2370 - val_accuracy: 0.9696 - val_auc: 0.9767
# Epoch 49/50
# 93/93 [==============================] - 10s 110ms/step - loss: 0.0256 - accuracy: 0.9907 - auc: 0.9992 - val_loss: 0.2556 - val_accuracy: 0.9544 - val_auc: 0.9771
# Epoch 50/50
# 93/93 [==============================] - 10s 111ms/step - loss: 0.0240 - accuracy: 0.9937 - auc: 0.9990 - val_loss: 0.2280 - val_accuracy: 0.9514 - val_auc: 0.9839

# %%
pd.DataFrame(history.history)[['accuracy','val_accuracy']].plot()
plt.title("Accuracy")
plt.show()

pd.DataFrame(history.history)[['loss','val_loss']].plot()
plt.title("Loss")
plt.show()

results = model.evaluate(test_images, verbose=0)

printmd(" ## Test Loss: {:.5f}".format(results[0]))
printmd("## Accuracy on the test set: {:.2f}%".format(results[1] * 100))
print('\n')
# Out:
#  ## Test Loss: 0.28254
# ## Accuracy on the test set: 95.37%

# %%
# Predict the label of the test_images:
pred = model.predict(test_images)
pred = np.argmax(pred,axis=1)

# Map the label
labels = (train_images.class_indices)
labels = dict((v,k) for k,v in labels.items())
pred = [labels[k] for k in pred]

from sklearn.metrics import classification_report
y_test = list(test_df.Label)
from sklearn import metrics
print('Accuracy:', np.round(metrics.accuracy_score(y_test,pred),5))
print('Precision:', np.round(metrics.precision_score(y_test,pred, average='weighted'),5))
print('Recall:', np.round(metrics.recall_score(y_test,pred, average='weighted'),5))
print('F1 Score:', np.round(metrics.f1_score(y_test,pred, average='weighted'),5))
print('Cohen Kappa Score:', np.round(metrics.cohen_kappa_score(y_test,pred),5))
print(classification_report(y_test, pred))
# Out:
# Accuracy: 0.95368
# Precision: 0.95485
# Recall: 0.95368
# F1 Score: 0.95369
# Cohen Kappa Score: 0.9074
#               precision    recall  f1-score   support
#
#           DR       0.98      0.93      0.95       190
#        No_DR       0.93      0.98      0.95       177
#
#     accuracy                           0.95       367
#    macro avg       0.95      0.95      0.95       367
# weighted avg       0.95      0.95      0.95       367

# %%
cf_matrix = confusion_matrix(y_test, pred, normalize='true')
plt.figure(figsize = (10,6))
sns.heatmap(cf_matrix, annot=True, xticklabels = sorted(set(y_test)), yticklabels = sorted(set(y_test)))
plt.title('Normalized Confusion Matrix')
plt.show()
